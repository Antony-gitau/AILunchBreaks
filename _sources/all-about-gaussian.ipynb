# %% [markdown]
# # All about Gaussians

# %% [markdown]
# Gaussian are a popular distribution. They are used because they are easy to use. They are also easy to manipulate. Like when you add one gaussian with another you still get a gaussian. They can be conditioned. they can be marginalized.

# %%
import pandas as pd

# %%
# !pwd
