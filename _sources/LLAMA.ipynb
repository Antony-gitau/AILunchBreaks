# %% [markdown]
# # Friendly intro to the LLAMA Architecture

# %% [markdown]
# In this notebook, I want to use visualizations, PyTorch and mathematical equations to explain technical details of the LLAMA architecture as I understand it.
#
# - LLAMA is a family of LLMS thats trained by Meta.
# - Its based on vanilla tranformer architecture (Attention is all you need paper) expect that it makes use of decoder only.
# - The decoder architecture is built of the following main architectural parts

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
